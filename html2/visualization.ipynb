# %%
import plotly.express as px
import pandas as pd

# to run this code, using jupyter on VS Code
from plotly.offline import plot
import plotly.io as pio
pio.renderers.default = "notebook_connected"
# pio.renderers.default = "browser"
# pio.renderers.default = "webgl"

from dash import Dash, html, dcc
from dash.dependencies import Input, Output, State

# %%
df = px.data.gapminder()
fig = px.scatter(df, x="gdpPercap", y="lifeExp", size="pop", color="continent",
              hover_name="country", log_x=True, size_max=60, title="Gapminder", height=650, trendline="ols", template="plotly_dark", range_y=[20, 90])
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# 3           4
# 4           4
# ...       ...
# 1699      716
# 1700      716
# 1701      716
# 1702      716
# 1703      716
#
# [1704 rows x 8 columns]

# %%
app = Dash(__name__, external_stylesheets=["https://codepen.io/chriddyp/pen/bWLwgP.css"])
app.layout = html.Div(
    [
        html.Div([
            html.Ul([
                html.Li(html.A([
                    html.Span(ClassName="icon"),
                    html.Span("Home", className="title"),
                ], href="#")),
                html.Li(html.A([
                    html.Span(ClassName="icon"),
                    html.Span("Home", className="title"),
                ], href="#")),
                html.Li(html.A([
                    html.Span(ClassName="icon"),
                    html.Span("Home", className="title"),
                ], href="#")),
                html.Li(html.A([
                    html.Span(ClassName="icon"),
                    html.Span("Home", className="title"),
                ], href="#"))
            ])
        ], className="navigation"),
    ], className="container"
)


app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [05/Apr/2022 15:05:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Apr/2022 15:05:01] "GET /assets/header.css?m=1647850922.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Apr/2022 15:05:01] "GET /assets/main.css?m=1647855052.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Apr/2022 15:05:01] "GET /assets/typography.css?m=1647849124.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Apr/2022 15:05:01] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_3_1m1649163431.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Apr/2022 15:05:01] "GET /_dash-component-suites/dash/deps/react@16.v2_3_1m1649163431.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Apr/2022 15:05:02] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_3_1m1649163431.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Apr/2022 15:05:02] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_3_1m1649163431.7.2.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Apr/2022 15:05:02] "GET /assets/custom-script.js?m=1647861958.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Apr/2022 15:05:02] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v2_3_1m1649163431.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Apr/2022 15:05:02] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_3_0m1649163431.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Apr/2022 15:05:02] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.v2_3_0m1649163431.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Apr/2022 15:05:02] "GET /_dash-component-suites/dash/html/dash_html_components.v2_0_2m1649163432.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Apr/2022 15:05:02] "GET /_dash-component-suites/dash/dash_table/bundle.v5_1_1m1649163431.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Apr/2022 15:05:02] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Apr/2022 15:05:03] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Apr/2022 15:05:03] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Apr/2022 15:05:03] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Apr/2022 15:05:03] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Apr/2022 15:05:03] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Apr/2022 15:05:03] "GET /_favicon.ico?v=2.3.1 HTTP/1.1" 200 -

# %%
app = Dash(__name__, external_stylesheets=["https://codepen.io/chriddyp/pen/bWLwgP.css"])
app.layout = html.Div([
    dcc.Input(id="input-1", type="text", value=None),
    html.Div(id="output-1"),
])

@app.callback(
    Output(component_id="output-1", component_property="children"),
    [Input(component_id="input-1", component_property="value")]
)

# decorator callback function
def update_output_1(input_value):
    return f"You entered {input_value}"

app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [21/Mar/2022 13:31:02] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 13:31:02] "GET /assets/custom-script.js?m=1647861957.7601464 HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 13:31:03] "GET /_dash-component-suites/dash/dcc/dash_core_components.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 13:31:03] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 13:31:03] "GET /_dash-component-suites/dash/html/dash_html_components.min.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 13:31:03] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 13:31:03] "GET /_dash-component-suites/dash/dash_table/bundle.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 13:31:03] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 13:31:03] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 13:31:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 13:31:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 13:31:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 13:31:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 13:31:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 13:31:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 13:31:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 13:31:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 13:31:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 13:31:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 13:31:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 13:31:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 13:31:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 13:35:42] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -

# %%
app = Dash(__name__, external_stylesheets=["https://codepen.io/chriddyp/pen/bWLwgP.css"])
app.layout = html.Div([
    html.H1("Hello Dash", className="app-header--title"),
    dcc.Graph( id="graph-1", figure=fig),
    dcc.Graph( id="graph-2", figure=fig),
    dcc.Slider(min = df['year'].min(), max = df['year'].max(),step=5, id="year-slider", value=df['year'].min(), marks={str(year): str(year) for year in df['year'].unique()}),
    dcc.Dropdown(id="continent-dropdown", options=[{'label': i, 'value': i} for i in df['continent'].unique()], value= ['Asia'], multi = True),
    html.Button(id="submit-button", n_clicks=0, children="Submit"),
])

@app.callback(
    Output("graph-1", "figure"),
    Output("graph-2", "figure"),
    State("year-slider", "value"),
    State("continent-dropdown", "value"),
    Input("submit-button", "n_clicks")
    
)

# decorator callback function
def update_figure(selected_year, selected_continent, n_clicks):
    filtered_df = df[(df.year == selected_year) & (df.continent.isin(selected_continent))] 
    fig = px.scatter(filtered_df, x="gdpPercap", y="lifeExp", size="pop", color="continent", hover_name="country", log_x=True, size_max=60, title="Gapminder", height=650, range_y=[20, 100])
    return fig,fig

# def update_figure(selected_year):
#     filtered_df = df[df.year == selected_year]
#     traces = []
#     for i in filtered_df.continent.unique():
#         df_by_continent = filtered_df[filtered_df['continent'] == i]
#         traces.append(dict(
#             x=df_by_continent['gdpPercap'],
#             y=df_by_continent['lifeExp'],
#             text=df_by_continent['country'],
#             mode='markers',
#             opacity=0.7,
#             marker={
#                 'size': 15,
#                 'line': {'width': 0.5, 'color': 'white'}
#             },
#             name=i
#         ))

#     return {
#         'data': traces,
#         'layout': dict(
#             xaxis={'type': 'log', 'title': 'GDP Per Capita',
#                    'range':[2.3, 4.8]},
#             yaxis={'title': 'Life Expectancy', 'range': [20, 90]},
#             margin={'l': 40, 'b': 40, 't': 10, 'r': 10},
#             legend={'x': 0, 'y': 1},
#             hovermode='closest'
#         )
#     }

app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [21/Mar/2022 15:46:59] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 15:47:00] "GET /_dash-component-suites/dash/dcc/dash_core_components.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 15:47:00] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 15:47:00] "GET /_dash-component-suites/dash/html/dash_html_components.min.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 15:47:00] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 15:47:00] "GET /_dash-component-suites/dash/dash_table/bundle.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 15:47:00] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 15:47:00] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 15:47:00] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 15:47:00] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 15:47:00] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 15:47:00] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 15:47:01] "GET /_dash-component-suites/dash/dcc/async-graph.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 15:47:01] "GET /_dash-component-suites/dash/dcc/async-slider.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 15:47:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 15:47:01] "GET /_dash-component-suites/dash/dcc/async-dropdown.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 15:47:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 15:47:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Mar/2022 15:53:35] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Mar/2022 09:01:43] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Mar/2022 12:56:39] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Mar/2022 12:56:39] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Mar/2022 13:06:45] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Mar/2022 21:30:35] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Mar/2022 21:37:02] "GET /assets/main.css?m=1647855050.3481 HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Mar/2022 21:37:02] "GET /assets/header.css?m=1647850921.927277 HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Mar/2022 21:37:02] "GET /assets/typography.css?m=1647849122.143839 HTTP/1.1" 304 -
# 127.0.0.1 - - [22/Mar/2022 21:37:02] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_3_0m1647777510.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Mar/2022 21:37:02] "GET /_dash-component-suites/dash/deps/react@16.v2_3_0m1647777510.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Mar/2022 21:37:02] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_3_0m1647777510.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Mar/2022 21:37:02] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_3_0m1647777510.7.2.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Mar/2022 21:37:02] "GET /assets/custom-script.js?m=1647861957.7601464 HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Mar/2022 21:37:02] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v2_3_0m1647777510.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Mar/2022 21:37:02] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_3_0m1647777510.js HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Mar/2022 21:37:02] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.v2_3_0m1647777510.js HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Mar/2022 21:37:02] "GET /_dash-component-suites/dash/html/dash_html_components.v2_0_2m1647777510.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Mar/2022 21:37:02] "GET /_dash-component-suites/dash/dash_table/bundle.v5_1_1m1647777510.js HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Mar/2022 21:37:05] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Mar/2022 21:37:05] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Mar/2022 21:37:05] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Mar/2022 21:37:05] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Mar/2022 21:37:05] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Mar/2022 21:37:05] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Mar/2022 21:37:05] "POST /_dash-update-component HTTP/1.1" 200 -
