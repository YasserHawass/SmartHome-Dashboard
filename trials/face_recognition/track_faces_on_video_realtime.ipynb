# %% [markdown]
# ### This demo shows how to detect faces from video and displays result in realtime
#
# You need OpenCV installed to run this example. To install it, run ___pip install opencv-python___

# %%
# !pip install mediapipe
# !pip install dash_extensions
# !pip install quart
# Out:
# Collecting mediapipe
#   Using cached mediapipe-0.8.9.1-cp39-cp39-win_amd64.whl (48.5 MB)
# Requirement already satisfied: numpy in c:\users\mahaw\anaconda3\lib\site-packages (from mediapipe) (1.20.3)
# Collecting opencv-contrib-python
#   Using cached opencv_contrib_python-4.5.5.64-cp36-abi3-win_amd64.whl (42.2 MB)
# Requirement already satisfied: matplotlib in c:\users\mahaw\anaconda3\lib\site-packages (from mediapipe) (3.4.3)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\mahaw\anaconda3\lib\site-packages (from mediapipe) (21.2.0)
# Requirement already satisfied: protobuf>=3.11.4 in c:\users\mahaw\anaconda3\lib\site-packages (from mediapipe) (3.20.0)
# Collecting absl-py
#   Using cached absl_py-1.0.0-py3-none-any.whl (126 kB)
# Requirement already satisfied: six in c:\users\mahaw\anaconda3\lib\site-packages (from absl-py->mediapipe) (1.16.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mahaw\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\mahaw\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mahaw\anaconda3\lib\site-packages (from matplotlib->mediapipe) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mahaw\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mahaw\anaconda3\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Installing collected packages: opencv-contrib-python, absl-py, mediapipe
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\mahaw\\anaconda3\\Lib\\site-packages\\cv2\\cv2.pyd'
# Consider using the `--user` option or check the permissions.
# Collecting dash_extensions
#   Downloading dash_extensions-0.0.71-py3-none-any.whl (1.6 MB)
# Requirement already satisfied: more-itertools in c:\users\mahaw\anaconda3\lib\site-packages (from dash_extensions) (8.10.0)
# Collecting jsbeautifier
#   Downloading jsbeautifier-1.14.2.tar.gz (73 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting Flask-Caching
#   Downloading Flask_Caching-1.10.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: dash in c:\users\mahaw\anaconda3\lib\site-packages (from dash_extensions) (2.3.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\mahaw\anaconda3\lib\site-packages (from dash->dash_extensions) (1.1.2)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\mahaw\anaconda3\lib\site-packages (from dash->dash_extensions) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\mahaw\anaconda3\lib\site-packages (from dash->dash_extensions) (2.0.0)
# Requirement already satisfied: flask-compress in c:\users\mahaw\anaconda3\lib\site-packages (from dash->dash_extensions) (1.11)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\mahaw\anaconda3\lib\site-packages (from dash->dash_extensions) (5.6.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\mahaw\anaconda3\lib\site-packages (from dash->dash_extensions) (5.0.0)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\mahaw\anaconda3\lib\site-packages (from Flask>=1.0.4->dash->dash_extensions) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\mahaw\anaconda3\lib\site-packages (from Flask>=1.0.4->dash->dash_extensions) (2.0.2)
# Requirement already satisfied: click>=5.1 in c:\users\mahaw\anaconda3\lib\site-packages (from Flask>=1.0.4->dash->dash_extensions) (8.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\mahaw\anaconda3\lib\site-packages (from Flask>=1.0.4->dash->dash_extensions) (2.11.3)
# Requirement already satisfied: colorama in c:\users\mahaw\anaconda3\lib\site-packages (from click>=5.1->Flask>=1.0.4->dash->dash_extensions) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\mahaw\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash->dash_extensions) (1.1.1)
# Requirement already satisfied: six in c:\users\mahaw\anaconda3\lib\site-packages (from plotly>=5.0.0->dash->dash_extensions) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\mahaw\anaconda3\lib\site-packages (from plotly>=5.0.0->dash->dash_extensions) (8.0.1)
# Requirement already satisfied: brotli in c:\users\mahaw\anaconda3\lib\site-packages (from flask-compress->dash->dash_extensions) (1.0.9)
# Collecting editorconfig>=0.12.2
#   Downloading EditorConfig-0.12.3-py3-none-any.whl (16 kB)
# Building wheels for collected packages: jsbeautifier
#   Building wheel for jsbeautifier (PEP 517): started
#   Building wheel for jsbeautifier (PEP 517): finished with status 'done'
#   Created wheel for jsbeautifier: filename=jsbeautifier-1.14.2-py3-none-any.whl size=92132 sha256=0c340311c1365f561bba341e9d593f71a9ab107882aba5c43b405206cd54a1fb
#   Stored in directory: c:\users\mahaw\appdata\local\pip\cache\wheels\f2\98\ac\0a96e6850fcec709c1ff8c1edeac4b63282107804a0826c859
# Successfully built jsbeautifier
# Installing collected packages: editorconfig, jsbeautifier, Flask-Caching, dash-extensions
# Successfully installed Flask-Caching-1.10.1 dash-extensions-0.0.71 editorconfig-0.12.3 jsbeautifier-1.14.2
# Collecting quart
#   Downloading Quart-0.17.0-py3-none-any.whl (91 kB)
# Collecting hypercorn>=0.11.2
#   Downloading Hypercorn-0.13.2-py3-none-any.whl (56 kB)
# Requirement already satisfied: toml in c:\users\mahaw\anaconda3\lib\site-packages (from quart) (0.10.2)
# Requirement already satisfied: markupsafe in c:\users\mahaw\anaconda3\lib\site-packages (from quart) (1.1.1)
# Requirement already satisfied: werkzeug>=2.0.0 in c:\users\mahaw\anaconda3\lib\site-packages (from quart) (2.0.2)
# Requirement already satisfied: jinja2 in c:\users\mahaw\anaconda3\lib\site-packages (from quart) (2.11.3)
# Collecting aiofiles
#   Downloading aiofiles-0.8.0-py3-none-any.whl (13 kB)
# Collecting blinker
#   Downloading blinker-1.4.tar.gz (111 kB)
# Requirement already satisfied: click in c:\users\mahaw\anaconda3\lib\site-packages (from quart) (8.1.2)
# Requirement already satisfied: itsdangerous in c:\users\mahaw\anaconda3\lib\site-packages (from quart) (2.0.1)
# Requirement already satisfied: h11 in c:\users\mahaw\anaconda3\lib\site-packages (from hypercorn>=0.11.2->quart) (0.13.0)
# Collecting wsproto>=0.14.0
#   Using cached wsproto-1.1.0-py3-none-any.whl (24 kB)
# Collecting h2>=3.1.0
#   Downloading h2-4.1.0-py3-none-any.whl (57 kB)
# Collecting priority
#   Downloading priority-2.0.0-py3-none-any.whl (8.9 kB)
# Collecting hpack<5,>=4.0
#   Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Collecting hyperframe<7,>=6.0
#   Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: colorama in c:\users\mahaw\anaconda3\lib\site-packages (from click->quart) (0.4.4)
# Building wheels for collected packages: blinker
#   Building wheel for blinker (setup.py): started
#   Building wheel for blinker (setup.py): finished with status 'done'
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13478 sha256=f15312dcac976f1f86c1ee57b9f0c4174cc4e17ffd54198aad9496ceb2bf4c40
#   Stored in directory: c:\users\mahaw\appdata\local\pip\cache\wheels\50\93\f8\4f0a42a03a06626d675f13907b6982ad5ecff383530af5a900
# Successfully built blinker
# Installing collected packages: hyperframe, hpack, wsproto, priority, h2, hypercorn, blinker, aiofiles, quart
# Successfully installed aiofiles-0.8.0 blinker-1.4 h2-4.1.0 hpack-4.0.0 hypercorn-0.13.2 hyperframe-6.0.1 priority-2.0.0 quart-0.17.0 wsproto-1.1.0

# %%
# %pylab inline 
import face_recognition
import cv2
import matplotlib.patches as patches
from IPython.display import clear_output
from matplotlib.pyplot import imshow
import matplotlib.pylab as plt



import asyncio
import base64
import mediapipe as mp
import threading
from quart import Quart, websocket
from dash_extensions import WebSocket
import dash

import plotly.express as px
import pandas as pd

# to run this code, using jupyter on VS Code
from plotly.offline import plot
import plotly.io as pio
# pio.renderers.default = "notebook_connected"
# pio.renderers.default = "browser"
# pio.renderers.default = "webgl"

from dash import Dash, html, dcc
from dash.dependencies import Input, Output, State
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\mahaw\anaconda3\lib\site-packages\IPython\core\magics\pylab.py:159: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
# Loading video for face detection
# video_capture = cv2.VideoCapture("../hamilton_clip.mp4")
video_capture = cv2.VideoCapture(1)

frame_count = 0

while video_capture.isOpened():    
    # Grab a single frame of video
    ret, frame = video_capture.read()

    # Bail out when the video file ends
    if not ret:
        video_capture.release()
        break
        
    # We will search face in every 15 frames to speed up process.
    frame_count += 1
    if frame_count % 15 == 0:    
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # Display video frame
        title("Input Stream")
        plt.imshow(frame)        

        # Find all the faces and face encodings in the current frame of video
        rgb_frame = frame[:, :, ::-1]
        face_locations = face_recognition.face_locations(rgb_frame)
        
        # If faces were found, we will mark it on frame with blue dots
        for face_location in face_locations:
            plt.plot(face_location[1], face_location[0], 'bo')
            plt.plot(face_location[1], face_location[2], 'bo')
            plt.plot(face_location[3], face_location[2], 'bo')
            plt.plot(face_location[3], face_location[0], 'bo')

        # Show frame...
        plt.show() 
        # ... and hold it until a new frame appears
        clear_output(wait=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26740/2072094213.py in <module>
#       7 while video_capture.isOpened():
#       8     # Grab a single frame of video
# ----> 9     ret, frame = video_capture.read()
#      10
#      11     # Bail out when the video file ends
#
# KeyboardInterrupt:

# %%
# Loading video for face detection
# video_capture = cv2.VideoCapture("../hamilton_clip.mp4")
video_capture = cv2.VideoCapture(0)

frame_count = 0

while video_capture.isOpened():    
    # Grab a single frame of video
    ret, frame = video_capture.read()

    # Bail out when the video file ends
    if not ret:
        video_capture.release()
        break
        
    # We will search face in every 15 frames to speed up process.
    frame_count += 1
    if frame_count % 15 == 0:    
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # Display video frame
        title("Input Stream")
        
        plt.imshow(frame)        

        # Find all the faces and face encodings in the current frame of video
        rgb_frame = frame[:, :, ::-1]
        face_locations = face_recognition.face_locations(rgb_frame)
        
        # If faces were found, we will mark it on frame with blue dots
        for face_location in face_locations:        
            plt.plot(face_location[1], face_location[0], 'bo')
            plt.plot(face_location[1], face_location[2], 'bo')
            plt.plot(face_location[3], face_location[2], 'bo')
            plt.plot(face_location[3], face_location[0], 'bo')

        # Show frame...
        plt.show() 
        # ... and hold it until a new frame appears
        clear_output(wait=True)

# %%
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose


class VideoCamera(object):
    def __init__(self, video_path):
        self.video = cv2.VideoCapture(video_path)

    def __del__(self):
        self.video.release()

    def get_frame(self):
        ret, frame = video_capture.read()
            
        # We will search face in every 15 frames to speed up process.
        frame_count += 1
        if frame_count % 15 == 0:    
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frame.flags.writeable = True
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            gb_frame = frame[:, :, ::-1]
            face_locations = face_recognition.face_locations(rgb_frame)
            mp_drawing.draw_landmarks(frame, face_location, mp_drawing.DrawingSpec(color=(0, 255, 0), alpha=0.7))
            _, jpeg = cv2.imencode('.jpg', frame)
            return jpeg.tobytes()
            # plt.imshow(frame)        

            # Find all the faces and face encodings in the current frame of video
            rgb_frame = frame[:, :, ::-1]
            face_locations = face_recognition.face_locations(rgb_frame)
            
            # If faces were found, we will mark it on frame with blue dots
            for face_location in face_locations:        
                plt.plot(face_location[1], face_location[0], 'bo')
                plt.plot(face_location[1], face_location[2], 'bo')
                plt.plot(face_location[3], face_location[2], 'bo')
                plt.plot(face_location[3], face_location[0], 'bo')

        # with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
            # success, image = self.video.read()

            # # Recolor image to RGB
            # image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            # image.flags.writeable = False

            # # Make detection
            # results = pose.process(image)

            # # Recolor back to BGR
            # image.flags.writeable = True
            # image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # # Render detections
            # mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
            #                           mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
            #                           mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
            #                           )

            # _, jpeg = cv2.imencode('.jpg', image)
            # return jpeg.tobytes()


# Setup small Quart server for streaming via websocket, one for each stream.
server = Quart(__name__)
n_streams = 2


async def stream(camera, delay=None):
    while True:
        if delay is not None:
            await asyncio.sleep(delay)  # add delay if CPU usage is too high
        frame = camera.get_frame()
        await websocket.send(f"...{base64.b64encode(frame).decode()}")


@server.websocket("/stream0")
async def stream0():
    camera = VideoCamera(0)
    await stream(camera)


@server.websocket("/stream1")
async def stream1():
    camera = VideoCamera(0)
    await stream(camera)


# Create small Dash application for UI.
app = dash.Dash(__name__)
app.layout = html.Div(
    [html.Img(style={'width': '40%', 'padding': 10}, id=f"v{i}") for i in range(n_streams)] +
    [WebSocket(url=f"ws://127.0.0.1:5000/stream{i}", id=f"ws{i}") for i in range(n_streams)]
)
# Copy data from websockets to Img elements.
for i in range(n_streams):
    app.clientside_callback("function(m){return m? m.data : '';}", Output(f"v{i}", "src"), Input(f"ws{i}", "message"))

if __name__ == '__main__':
    threading.Thread(target=app.run_server).start()
    server.run()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Quart app '__main__'
#  * Environment: production
#  * Please use an ASGI server (e.g. Hypercorn) directly in production
#  * Debug mode: False
#  * Running on http://127.0.0.1:5000 (CTRL + C to quit)
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\quart\app.py in run(self, host, port, debug, use_reloader, loop, ca_certs, certfile, keyfile, **kwargs)
#    1269         try:
# -> 1270             loop.run_until_complete(task)
#    1271         finally:
#
# ~\anaconda3\lib\asyncio\base_events.py in run_until_complete(self, future)
#     617         self._check_closed()
# --> 618         self._check_running()
#     619
#
# ~\anaconda3\lib\asyncio\base_events.py in _check_running(self)
#     579         if events._get_running_loop() is not None:
# --> 580             raise RuntimeError(
#     581                 'Cannot run the event loop while another loop is running')
#
# RuntimeError: Cannot run the event loop while another loop is running
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25424/2872924225.py in <module>
#      98 if __name__ == '__main__':
#      99     threading.Thread(target=app.run_server).start()
# --> 100     server.run()
#
# ~\anaconda3\lib\site-packages\quart\app.py in run(self, host, port, debug, use_reloader, loop, ca_certs, certfile, keyfile, **kwargs)
#    1272             try:
#    1273                 _cancel_all_tasks(loop)
# -> 1274                 loop.run_until_complete(loop.shutdown_asyncgens())
#    1275             finally:
#    1276                 asyncio.set_event_loop(None)
#
# ~\anaconda3\lib\asyncio\base_events.py in run_until_complete(self, future)
#     616         """
#     617         self._check_closed()
# --> 618         self._check_running()
#     619
#     620         new_task = not futures.isfuture(future)
#
# ~\anaconda3\lib\asyncio\base_events.py in _check_running(self)
#     578             raise RuntimeError('This event loop is already running')
#     579         if events._get_running_loop() is not None:
# --> 580             raise RuntimeError(
#     581                 'Cannot run the event loop while another loop is running')
#     582
#
# RuntimeError: Cannot run the event loop while another loop is running
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [04/Apr/2022 09:36:45] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:36:45] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_3_0m1647777510.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:36:45] "GET /_dash-component-suites/dash/deps/react@16.v2_3_0m1647777510.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:36:45] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_3_0m1647777510.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:36:45] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_3_0m1647777510.7.2.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:36:45] "GET /_dash-component-suites/dash_extensions/dash_extensions.v0_0_71m1649056792.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:36:45] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v2_3_0m1647777510.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:36:45] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_3_0m1647777510.js HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:36:45] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.v2_3_0m1647777510.js HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:36:45] "GET /_dash-component-suites/dash/dash_table/bundle.v5_1_1m1647777510.js HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:36:45] "GET /_dash-component-suites/dash/html/dash_html_components.v2_0_2m1647777510.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:36:45] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:36:45] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:36:46] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:38:34] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:38:34] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:38:34] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:38:34] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:39:03] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:39:03] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:39:03] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:39:03] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:39:46] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:39:46] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:39:46] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:39:46] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:40:26] "GET /stream0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:40:26] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:40:26] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:41:37] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:43:13] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:43:13] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:43:13] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:43:13] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:43:14] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:43:14] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:43:14] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:43:14] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:43:38] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:43:38] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:43:38] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:43:38] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:45:39] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:45:39] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:45:39] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:45:40] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:45:43] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:45:43] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:45:43] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:45:43] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:46:59] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:46:59] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:46:59] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:46:59] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:47:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:47:01] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:47:01] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:47:01] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:50:07] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:51:43] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:51:43] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:51:43] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:51:43] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:53:03] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:53:03] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:53:03] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:53:03] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:53:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:53:06] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:53:06] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:53:06] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:56:23] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:56:47] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:56:49] "GET /stream HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:56:49] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:56:49] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:56:50] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:57:00] "GET /stream0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:57:00] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:57:00] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:58:08] "GET /_dash-component-suites/dash_extensions/dash_extensions.min.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:58:08] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:58:08] "GET /_dash-component-suites/dash/dcc/dash_core_components.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:58:08] "GET /_dash-component-suites/dash/html/dash_html_components.min.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 09:58:08] "GET /_dash-component-suites/dash/dash_table/bundle.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:04:55] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:06:37] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:07:20] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:07:20] "GET /_dash-component-suites/dash_extensions/dash_extensions.min.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:07:20] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:07:20] "GET /_dash-component-suites/dash/dcc/dash_core_components.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:07:20] "GET /_dash-component-suites/dash/html/dash_html_components.min.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:07:20] "GET /_dash-component-suites/dash/dash_table/bundle.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:07:20] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:07:20] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:07:20] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:07:24] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:07:25] "GET /_dash-component-suites/dash_extensions/dash_extensions.min.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:07:25] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:07:25] "GET /_dash-component-suites/dash/dcc/dash_core_components.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:07:25] "GET /_dash-component-suites/dash/html/dash_html_components.min.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:07:25] "GET /_dash-component-suites/dash/dash_table/bundle.js.map HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:07:25] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:07:25] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:07:25] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:08:58] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:08:58] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:08:58] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:08:58] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:08:59] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:08:59] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:08:59] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:08:59] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:09:00] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:09:00] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:09:00] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:09:00] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:09:02] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:09:02] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:09:02] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:09:02] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:11:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:11:06] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:11:06] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:11:06] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:11:37] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:11:38] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:11:38] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:11:38] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:11:41] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:11:41] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:11:41] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:11:41] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:12:10] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:12:10] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:12:10] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:12:10] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:12:11] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:12:11] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:12:11] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:12:11] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:12:12] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:12:12] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:12:12] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:12:12] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:12:13] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:12:13] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:12:13] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:12:13] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:12:14] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:12:14] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:12:14] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:12:14] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:13:17] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:13:17] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:13:17] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:13:17] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:15:16] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:18:29] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:18:29] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:18:29] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:18:29] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:18:31] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:18:32] "GET /_dash-layout HTTP/1.1" 200 -
# C:\Users\mahaw\anaconda3\lib\site-packages\flask\ctx.py:288: RuntimeWarning:
#
# coroutine 'BaseEventLoop.shutdown_asyncgens' was never awaited
#
# C:\Users\mahaw\anaconda3\lib\site-packages\flask\ctx.py:288: RuntimeWarning:
#
# coroutine 'serve' was never awaited
#
# 127.0.0.1 - - [04/Apr/2022 10:18:32] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:18:32] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:18:34] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:18:34] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:18:34] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:18:34] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:18:49] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:18:50] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:18:50] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:18:50] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:18:53] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:18:54] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:18:54] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:18:54] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:19:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:19:01] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:19:01] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:19:01] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:19:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:19:44] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:19:44] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:19:45] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:19:46] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:19:46] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:19:46] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:19:46] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:19:46] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:19:47] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:19:47] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:19:47] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:19:49] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:19:49] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:19:49] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:19:49] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:19:55] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:19:55] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:19:55] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:19:55] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:20:11] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:20:11] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:20:11] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:20:11] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:20:13] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:20:13] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:20:13] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:20:13] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:20:15] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:20:15] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:20:15] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:20:15] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:20:16] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:20:16] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:20:16] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:20:16] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:20:19] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:20:19] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:20:19] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:20:19] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:20:54] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:20:54] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:20:54] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Apr/2022 10:20:54] "GET /_favicon.ico?v=2.3.0 HTTP/1.1" 200 -
